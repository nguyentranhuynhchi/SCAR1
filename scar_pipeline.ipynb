# %% [markdown]
# # Pipeline Huấn luyện SCAR (Prompt-free SSPANet + CMSPA M3)
# > **Kiến trúc:** Phân đoạn CMR 3 phương thái (**bSSFP/CINE, LGE, T2w**) trên **MyoPS-380** sử dụng **3 ResNetV2 encoders độc lập + SSPANet (RMS Strip Pooling Attention) + CMSPA (Cross-Modal Strip Pathology Attention) + 1 Decoder**.
# > Pipeline Prompt-free loại bỏ hoàn toàn phụ thuộc CLIP/MLLM, tối ưu bộ nhớ VRAM và xuất raw logits 4 kênh canonical (`0: background, 1: normal, 2: edema, 3: scar`).
#
# ---
# ### 🔗 Tài nguyên chuẩn bị trên Google Drive:
# 1. **Pretrained Weights:** `R50-ViT-B_16.npz` (Trọng số ResNetV2 ImageNet21k để khởi tạo cả 3 nhánh encoder).
# 2. **Bộ dữ liệu MyoPS380:** Thư mục `MyoPS380_dataset` trên Google Drive (`Processed_data` hoặc `Raw_data`).

# %% [markdown]
# ## Bước 1: Kiểm tra GPU & Kết nối Google Drive
# Đảm bảo bạn đã kích hoạt **GPU** trong Colab (`Runtime` -> `Change runtime type` -> Chọn `T4 GPU` hoặc `A100`).

# %%
# 1. Kiểm tra cấu hình GPU
# !nvidia-smi

# 2. Kết nối Google Drive để lưu trữ và tải dữ liệu/weights
from google.colab import drive
import os
from pathlib import Path

drive.mount('/content/drive')
# Out:
# Mon Sep  7 15:06:49 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Mounted at /content/drive

# %% [markdown]
# ## 📥 Bước 2: Clone Repository SCAR mới nhất
# Clone mã nguồn SCAR từ GitHub về môi trường Colab.

# %%
# %cd /content
# !rm -rf SCAR
# !git clone https://github.com/nguyentranhuynhchi/SCAR1.git SCAR
# %cd /content/SCAR
print("Thư mục làm việc hiện tại:", os.getcwd())
# Out:
# /content
# Cloning into 'SCAR'...
# remote: Enumerating objects: 340, done.
# remote: Counting objects: 100% (340/340), done.
# remote: Compressing objects: 100% (223/223), done.
# remote: Total 340 (delta 123), reused 311 (delta 94), pack-reused 0 (from 0)
# Receiving objects: 100% (340/340), 444.70 KiB | 14.34 MiB/s, done.
# Resolving deltas: 100% (123/123), done.
# /content/SCAR
# Thư mục làm việc hiện tại: /content/SCAR

# %% [markdown]
# ## Bước 3: Cài đặt các thư viện cần thiết
# Cài đặt trực tiếp từ file `requirements.txt` chuẩn của repository SCAR.

# %%
# !pip install -r requirements.txt
import torch
print("PyTorch Version:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device Name:", torch.cuda.get_device_name(0))
# Out:
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 2)) (2.11.0+cu128)
# Requirement already satisfied: numpy<3,>=1.24 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: scipy<2,>=1.10 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 4)) (1.16.3)
# Requirement already satisfied: nibabel<6,>=5.2 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 5)) (5.4.2)
# Requirement already satisfied: h5py<4,>=3.11 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 6)) (3.16.0)
# Collecting ml-collections<2,>=0.1.1 (from -r requirements.txt (line 7))
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: PyYAML<7,>=6.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: tqdm<5,>=4.66 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 9)) (4.67.3)
# Requirement already satisfied: tensorboard<3,>=2.18 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: pandas<4,>=2.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 11)) (2.2.3)
# Requirement already satisfied: matplotlib<4,>=3.8 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 12)) (3.10.0)
# Requirement already satisfied: pytest<10,>=8 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 13)) (8.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (3.32.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.3->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.3->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.13/dist-packages (from nibabel<6,>=5.2->-r requirements.txt (line 5)) (26.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.13/dist-packages (from ml-collections<2,>=0.1.1->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.13/dist-packages (from tensorboard<3,>=2.18->-r requirements.txt (line 10)) (1.83.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.13/dist-packages (from tensorboard<3,>=2.18->-r requirements.txt (line 10)) (3.10.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from tensorboard<3,>=2.18->-r requirements.txt (line 10)) (11.3.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.13/dist-packages (from tensorboard<3,>=2.18->-r requirements.txt (line 10)) (5.29.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard<3,>=2.18->-r requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from tensorboard<3,>=2.18->-r requirements.txt (line 10)) (3.1.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas<4,>=2.0->-r requirements.txt (line 11)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<4,>=2.0->-r requirements.txt (line 11)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<4,>=2.0->-r requirements.txt (line 11)) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 12)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 12)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 12)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 12)) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.8->-r requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.13/dist-packages (from pytest<10,>=8->-r requirements.txt (line 13)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.13/dist-packages (from pytest<10,>=8->-r requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.13/dist-packages (from pytest<10,>=8->-r requirements.txt (line 13)) (2.21.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch<3,>=2.3->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas<4,>=2.0->-r requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from werkzeug>=1.0.1->tensorboard<3,>=2.18->-r requirements.txt (line 10)) (3.0.3)
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: ml-collections
# Successfully installed ml-collections-1.1.0
# PyTorch Version: 2.11.0+cu128
# CUDA Available: True
# Device Name: Tesla T4

# %% [markdown]
# ## Bước 4: Chuẩn bị Pretrained Weights (`R50-ViT-B_16.npz`)
# Trọng số này sẽ được nạp đồng bộ vào cả 3 nhánh encoder ResNetV2 (CINE, LGE, T2w) khi huấn luyện.
# Hệ thống sẽ ưu tiên copy từ Google Drive cá nhân của bạn, nếu chưa có sẽ tự động tải trực tiếp từ server Google ViT ImageNet21k.

# %%
# Tạo thư mục chứa weights
# !mkdir -p /content/SCAR/model/vit_checkpoint/imagenet21k

# CÁCH 1: Copy từ Google Drive cá nhân (Chuẩn đường dẫn Drive của bạn)
drive_vit_path = "/content/drive/MyDrive/NCKH_V2/i_mmseg/ViT_checkpoint/R50-ViT-B_16.npz"

if os.path.exists(drive_vit_path):
    # !cp "$drive_vit_path" /content/SCAR/model/vit_checkpoint/imagenet21k/R50-ViT-B_16.npz
    print("✅ Đã copy R50-ViT-B_16.npz từ Google Drive cá nhân!")
else:
    print("⚠️ Không tìm thấy file trong Drive cá nhân. Đang tự động tải từ server Google ViT...")
    # CÁCH 2: Tải trực tiếp từ server Google ViT ImageNet21k
    # !wget -c -O /content/SCAR/model/vit_checkpoint/imagenet21k/R50-ViT-B_16.npz https://storage.googleapis.com/vit_models/imagenet21k/R50+ViT-B_16.npz

# Kiểm tra file đã sẵn sàng
# !ls -lh /content/SCAR/model/vit_checkpoint/imagenet21k/
# Out:
# ✅ Đã copy R50-ViT-B_16.npz từ Google Drive cá nhân!
# total 440M
# -r-------- 1 root root 440M Sep  7 15:07 R50-ViT-B_16.npz

# %% [markdown]
# ## Bước 5: Chuẩn bị Dataset MyoPS380
# Sao chép thư mục dataset chuẩn từ Google Drive (`/content/drive/MyDrive/NCKH_V2/i_mmseg/MyoPS380_dataset`) vào môi trường Colab.

# %%
# Tạo thư mục MyoPS380_dataset trong project
# !mkdir -p /content/SCAR/MyoPS380_dataset

# Đường dẫn thư mục dataset trên Google Drive cá nhân (Chuẩn đường dẫn của bạn)
drive_dataset_dir = "/content/drive/MyDrive/NCKH_V2/i_mmseg/MyoPS380_dataset"

# Thư mục đích trong project trên Colab
target_dataset_dir = "/content/SCAR/MyoPS380_dataset"

if os.path.exists(drive_dataset_dir):
    print(f"Đang sao chép dataset từ Drive: {drive_dataset_dir}...")
    os.makedirs(target_dataset_dir, exist_ok=True)
    # !cp -r "$drive_dataset_dir"/* "$target_dataset_dir"/
    print("✅ Sao chép dataset thành công!")
    print("Các thư mục hiện có:")
    # !ls -la "$target_dataset_dir"
else:
    print(f"⚠️ Không tìm thấy thư mục: {drive_dataset_dir}")
    print("👉 Hãy kiểm tra lại xem thư mục MyoPS380_dataset nằm ở thư mục nào trong Drive của bạn.")
# Out:
# Đang sao chép dataset từ Drive: /content/drive/MyDrive/NCKH_V2/i_mmseg/MyoPS380_dataset...
# ✅ Sao chép dataset thành công!
# Các thư mục hiện có:
# total 16
# drwxr-xr-x 4 root root 4096 Sep  7 15:14 .
# drwxr-xr-x 7 root root 4096 Sep  7 15:07 ..
# dr-x------ 5 root root 4096 Sep  7 15:12 Processed_data
# dr-x------ 6 root root 4096 Sep  7 15:15 Raw_data

# %% [markdown]
# ## Bước 6: Tiền xử lý dữ liệu (Chỉ chạy nếu bạn dùng `Raw_data`)
# - Nếu bạn đã có sẵn `Processed_data`: Hệ thống sẽ tự động nhận diện và bỏ qua bước đóng gói này.
# - Nếu bạn dùng `Raw_data`: Script `preprocessing/process_and_save.py` sẽ chuẩn hóa cường độ về `[0, 1]`, bảo toàn test split benchmark (`preprocessing/splits/test_vol.txt`), và chuẩn hóa nhãn về canonical 4-class (`0: background, 1: normal, 2: edema, 3: scar`).

# %%
raw_data_dir = "/content/SCAR/MyoPS380_dataset/Raw_data"
processed_data_dir = "/content/SCAR/MyoPS380_dataset/Processed_data"

if os.path.exists(raw_data_dir) and not os.path.exists(os.path.join(processed_data_dir, "bSSFP", "train_npz")):
    print("Bắt đầu tiền xử lý dữ liệu Raw_data -> Processed_data...")
    # !python preprocessing/process_and_save.py \
        --src-path "$raw_data_dir" \
        --dst-path "$processed_data_dir" \
        --test-list preprocessing/splits/test_vol.txt \
        --label-order legacy \
        --normalization unit255 \
        --seed 1234
    print("✅ Tiền xử lý hoàn tất!")
elif os.path.exists(os.path.join(processed_data_dir, "bSSFP", "train_npz")):
    print("✅ Đã có Processed_data sẵn sàng để train!")
else:
    print("⚠️ Không tìm thấy Raw_data hoặc Processed_data. Hãy kiểm tra lại Bước 5!")
# Out:
# ✅ Đã có Processed_data sẵn sàng để train!

# %% [markdown]
# ## Bước 7: Kiểm tra sơ bộ (Sanity Check)
# Chạy thử nghiệm 1 chu trình forward/backward/AdamW đầy đủ trên GPU với AMP trước khi bắt đầu huấn luyện dài hạn.

# %% [markdown]
# ## Bước 8: Huấn luyện Mô hình CMSPA-Net (Ablation M3)
# Cấu hình chuẩn tối ưu cho SCAR:
# - Kiến trúc: `--ablation M3` (SSPANet + CMSPA)
# - Số epoch: `--epochs 300`, Tốc độ học: `--lr 0.001`
# - Dữ liệu: `--data-root /content/SCAR/MyoPS380_dataset/Processed_data`
# - Splits: `--list-dir data/processed/splits`
# - Khởi tạo trọng số: `--pretrained /content/SCAR/model/vit_checkpoint/imagenet21k/R50-ViT-B_16.npz`
# - Thư mục lưu kết quả: `--output-dir /content/SCAR/runs/M3`
# - Tự động dùng GPU CUDA và Mixed Precision (`--amp auto`)
#
# > 💡 **Lưu ý về Batch Size:** Mặc định `--batch-size 16` chạy tốt trên GPU Colab T4/A100 (15GB–40GB). Nếu dùng GPU nhỏ hơn (như GPU 4GB/6GB), bạn hãy đổi thành `--batch-size 2` kèm `--accum-steps 8`.

# %%
# !python preprocessing/build_splits.py \
    --data-root /content/SCAR/MyoPS380_dataset/Processed_data \
    --list-dir /content/SCAR/data/processed/splits \
    --test-list preprocessing/splits/test_vol.txt \
    --seed 1234
# Out:
# {
#   "patient_counts": {
#     "train": 243,
#     "val": 61,
#     "test_vol": 76
#   },
#   "sample_counts": {
#     "train": 1578,
#     "val": 394,
#     "val_vol": 61,
#     "test_vol": 76
#   },
#   "list_dir": "/content/SCAR/data/processed/splits"
# }

# %%
# Xóa thư mục run cũ nếu muốn train lại từ đầu
# !rm -rf /content/SCAR/runs/M2_Pro

# !python training/train.py \
    --config training/config/models/m2_pro.yaml \
    --ablation M2-PRO \
    --batch-size 32 \
    --accum-steps 1 \
    --lr 0.0003 \
    --epochs 300 \
    --output-dir /content/SCAR/runs/M2_Pro \
    --data-root /content/SCAR/MyoPS380_dataset/Processed_data \
    --list-dir /content/SCAR/data/processed/splits \
    --num-workers 2 \
    --pin-memory \
    --label-order canonical \
    --pretrained /content/SCAR/model/vit_checkpoint/imagenet21k/R50-ViT-B_16.npz
# Out:
# 2026-09-07 15:15:57,247 | INFO | Device cuda | AMP torch.bfloat16 | parameters 64,403,442 | train/val slices 1578/394 | effective batch <= 32
# 2026-09-07 15:15:57,247 | INFO | Selection: validation pixel-pooled mean foreground Dice; early stopping disabled (fixed ablation budget)
# 2026-09-07 15:16:00.299938: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-07 15:16:55,099 | INFO | train batch 20/50 | loss 0.61878 | ce 0.63367 | dice_loss 0.60389
# 2026-09-07 15:17:41,728 | INFO | train batch 40/50 | loss 0.46223 | ce 0.40556 | dice_loss 0.51890
# 2026-09-07 15:18:03,614 | INFO | train batch 50/50 | loss 0.42616 | ce 0.35455 | dice_loss 0.49778
# 2026-09-07 15:18:15,152 | INFO | val batch 13/13 | loss 0.30338 | ce 0.15184 | dice_loss 0.45493
# 2026-09-07 15:18:17,519 | INFO | New best checkpoint: epoch 1, validation Dice 0.41017 -> /content/SCAR/runs/M3/best.pth
# 2026-09-07 15:18:24,107 | INFO | Epoch 1/300 | train 0.42616 val 0.30338 | val Dice 0.41017 IoU 0.27573 | lr 0.001 | 137.4s | peak GPU 5199 MiB
# 2026-09-07 15:19:12,578 | INFO | train batch 20/50 | loss 0.26255 | ce 0.12800 | dice_loss 0.39709
# 2026-09-07 15:19:59,236 | INFO | train batch 40/50 | loss 0.25884 | ce 0.12556 | dice_loss 0.39211
# 2026-09-07 15:20:21,041 | INFO | train batch 50/50 | loss 0.25743 | ce 0.12413 | dice_loss 0.39073
# 2026-09-07 15:20:33,099 | INFO | val batch 13/13 | loss 0.25610 | ce 0.13839 | dice_loss 0.37381
# 2026-09-07 15:20:37,731 | INFO | New best checkpoint: epoch 2, validation Dice 0.53806 -> /content/SCAR/runs/M3/best.pth
# 2026-09-07 15
# 2026-09-07 17:03:36,817 | INFO | train batch 50/50 | loss 0.17670 | ce 0.06982 | dice_loss 0.28358
# 2026-09-07 17:03:48,359 | INFO | val batch 13/13 | loss 0.20809 | ce 0.08856 | dice_loss 0.32761
# 2026-09-07 17:03:51,396 | INFO | Epoch 47/300 | train 0.17670 val 0.20809 | val Dice 0.63158 IoU 0.48421 | lr 0.000861 | 130.9s | peak GPU 5194 MiB
# 2026-09-07 17:04:39,056 | INFO | train batch 20/50 | loss 0.17691 | ce 0.06952 | dice_loss 0.28430
# 2026-09-07 17:05:11,723 | ERROR | Training interrupted/failed; last.pth contains the last completed epoch if available.
# Traceback (most recent call last):
#   File "/content/SCAR/training/trainer/trainer.py", line 503, in trainer_Myops
#     train_metrics, global_step = run_epoch(
#                                  ~~~~~~~~~^
#         model,
#         ^^^^^^
#     ...<12 lines>...
#         global_step,
#         ^^^^^^^^^^^^
#     )
#     ^
#   File "/content/SCAR/training/trainer/trainer.py", line 210, in run_epoch
#     scaler.scale(losses["loss"] * batch_count).backward()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/_tensor.py", line 631, in backward
#     torch.autograd.backward(
#     ~~~~~~~~~~~~~~~~~~~~~~~^
#         self, gradient, retain_graph, create_graph, inputs=inputs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/autograd/__init__.py", line 381, in backward
#     _engine_run_backward(
#     ~~~~~~~~~~~~~~~~~~~~^
#         tensors,
#         ^^^^^^^^
#     ...<5 lines>...
#         accumulate_grad=True,
#         ^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/autograd/graph.py", line 869, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         t_outputs, *args, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )  # Calls into the C++ engine to run the backward pass
#     ^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/content/SCAR/training/train.py", line 219, in <module>
#     main()
#     ~~~~^^
#   File "/content/SCAR/training/train.py", line 215, in main
#     return Trainer(model, args, output).fit()
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/content/SCAR/training/trainer/trainer.py", line 332, in fit
#     return trainer_Myops(self.args, self.model, self.run_dir)
#   File "/content/SCAR/training/trainer/trainer.py", line 503, in trainer_Myops
#     train_metrics, global_step = run_epoch(
#                                  ~~~~~~~~~^
#         model,
#         ^^^^^^
#     ...<12 lines>...
#         global_step,
#         ^^^^^^^^^^^^
#     )
#     ^
#   File "/content/SCAR/training/trainer/trainer.py", line 210, in run_epoch
#     scaler.scale(losses["loss"] * batch_count).backward()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/_tensor.py", line 631, in backward
#     torch.autograd.backward(
#     ~~~~~~~~~~~~~~~~~~~~~~~^
#         self, gradient, retain_graph, create_graph, inputs=inputs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/autograd/__init__.py", line 381, in backward
#     _engine_run_backward(
#     ~~~~~~~~~~~~~~~~~~~~^
#         tensors,
#         ^^^^^^^^
#     ...<5 lines>...
#         accumulate_grad=True,
#         ^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/autograd/graph.py", line 869, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         t_outputs, *args, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )  # Calls into the C++ engine to run the backward pass
#     ^
# KeyboardInterrupt

# %% [markdown]
# ## Bước 9: Sao lưu Checkpoints & Kết quả vào Google Drive
# Sao lưu toàn bộ kết quả huấn luyện (gồm checkpoints `best.pth`, `last.pth`, logs và file `metrics.csv`) sang Google Drive cá nhân.

# %%
backup_drive_dir = "/content/drive/MyDrive/NCKH_V2/SCAR_runs/M2_Pro"
os.makedirs(backup_drive_dir, exist_ok=True)

# !cp -r /content/SCAR/runs/M2_Pro/* "$backup_drive_dir/"
print(f"✅ Đã sao lưu toàn bộ kết quả runs vào: {backup_drive_dir}")
# !ls -lh "$backup_drive_dir"

# %% [markdown]
# ## Bước 10: Đánh giá mô hình trên tập Test Volume (3D Testing)
# Thực hiện dự đoán và tính toán đầy đủ các chỉ số định lượng (Dice, HD95, ASD) trên toàn bộ các ca bệnh kiểm thử 3D trong `test_vol.txt`, đồng thời xuất các file dự đoán NIfTI để trực quan hóa giải phẫu.

# %%
# !python training/evaluate.py \
    --checkpoint /content/SCAR/runs/M2_Pro/best.pth \
    --data-root /content/SCAR/MyoPS380_dataset/Processed_data \
    --split test_vol \
    --device cuda \
    --amp auto \
    --batch-size 16 \
    --label-order canonical \
    --save-predictions
# Out:
# case0001: 3 slices, 0.795s, HD95 unit=unknown
# case0006: 3 slices, 0.140s, HD95 unit=unknown
# case0011: 3 slices, 0.131s, HD95 unit=unknown
# case0016: 3 slices, 0.111s, HD95 unit=unknown
# case0021: 3 slices, 0.086s, HD95 unit=unknown
# case0026: 3 slices, 0.101s, HD95 unit=unknown
# case0031: 3 slices, 0.100s, HD95 unit=unknown
# case0036: 6 slices, 0.213s, HD95 unit=unknown
# case0041: 7 slices, 0.184s, HD95 unit=unknown
# case0046: 6 slices, 0.163s, HD95 unit=unknown
# case0051: 8 slices, 0.252s, HD95 unit=unknown
# case0056: 5 slices, 0.177s, HD95 unit=unknown
# case0061: 6 slices, 0.176s, HD95 unit=unknown
# case0066: 7 slices, 0.224s, HD95 unit=unknown
# case0071: 7 slices, 0.191s, HD95 unit=unknown
# case0076: 8 slices, 0.303s, HD95 unit=unknown
# case0081: 7 slices, 0.228s, HD95 unit=unknown
# case0086: 4 slices, 0.230s, HD95 unit=unknown
# case0091: 6 slices, 0.329s, HD95 unit=unknown
# case0096: 4 slices, 0.138s, HD95 unit=unknown
# case0101: 6 slices, 0.415s, HD95 unit=unknown
# case0106: 2 slices, 0.122s, HD95 unit=unknown
# case0111: 7 slices, 0.269s, HD95 unit=unknown
# case0116: 6 slices, 0.315s, HD95 unit=unknown
# case0121: 8 slices, 0.291s, HD95 unit=unknown
# case0126: 3 slices, 0.156s, HD95 unit=unknown
# case0131: 6 slices, 0.256s, HD95 unit=unknown
# case0136: 3 slices, 0.172s, HD95 unit=unknown
# case0141: 8 slices, 0.349s, HD95 unit=unknown
# case0146: 4 slices, 0.119s, HD95 unit=unknown
# case0151: 6 slices, 0.301s, HD95 unit=unknown
# case0156: 7 slices, 0.313s, HD95 unit=unknown
# case0161: 5 slices, 0.258s, HD95 unit=unknown
# case0166: 7 slices, 0.298s, HD95 unit=unknown
# case0171: 6 slices, 0.206s, HD95 unit=unknown
# case0176: 6 slices, 0.180s, HD95 unit=unknown
# case0181: 7 slices, 0.186s, HD95 unit=unknown
# case0186: 6 slices, 0.158s, HD95 unit=unknown
# case0191: 5 slices, 0.134s, HD95 unit=unknown
# case0196: 10 slices, 0.265s, HD95 unit=unknown
# case0201: 7 slices, 0.188s, HD95 unit=unknown
# case0206: 5 slices, 0.136s, HD95 unit=unknown
# case0211: 6 slices, 0.162s, HD95 unit=unknown
# case0216: 3 slices, 0.109s, HD95 unit=unknown
# case0221: 7 slices, 0.184s, HD95 unit=unknown
# case0226: 7 slices, 0.187s, HD95 unit=unknown
# case0231: 9 slices, 0.244s, HD95 unit=unknown
# case0236: 7 slices, 0.192s, HD95 unit=unknown
# case0241: 7 slices, 0.206s, HD95 unit=unknown
# case0246: 3 slices, 0.093s, HD95 unit=unknown
# case0251: 7 slices, 0.182s, HD95 unit=unknown
# case0256: 6 slices, 0.164s, HD95 unit=unknown
# case0261: 9 slices, 0.239s, HD95 unit=unknown
# case0266: 9 slices, 0.239s, HD95 unit=unknown
# case0271: 7 slices, 0.191s, HD95 unit=unknown
# case0276: 7 slices, 0.187s, HD95 unit=unknown
# case0281: 10 slices, 0.262s, HD95 unit=unknown
# case0286: 5 slices, 0.134s, HD95 unit=unknown
# case0291: 9 slices, 0.240s, HD95 unit=unknown
# case0296: 8 slices, 0.211s, HD95 unit=unknown
# case0301: 9 slices, 0.238s, HD95 unit=unknown
# case0306: 8 slices, 0.221s, HD95 unit=unknown
# case0311: 9 slices, 0.235s, HD95 unit=unknown
# case0316: 6 slices, 0.165s, HD95 unit=unknown
# case0321: 8 slices, 0.213s, HD95 unit=unknown
# case0326: 3 slices, 0.091s, HD95 unit=unknown
# case0331: 8 slices, 0.209s, HD95 unit=unknown
# case0336: 4 slices, 0.113s, HD95 unit=unknown
# case0341: 6 slices, 0.176s, HD95 unit=unknown
# case0346: 3 slices, 0.103s, HD95 unit=unknown
# case0351: 8 slices, 0.212s, HD95 unit=unknown
# case0356: 8 slices, 0.210s, HD95 unit=unknown
# case0361: 8 slices, 0.211s, HD95 unit=unknown
# case0366: 6 slices, 0.168s, HD95 unit=unknown
# case0371: 9 slices, 0.235s, HD95 unit=unknown
# case0376: 6 slices, 0.160s, HD95 unit=unknown
# {
#   "edema": {
#     "cases": 76,
#     "status_counts": {
#       "missing_physical_geometry": 75,
#       "target_empty": 1
#     },
#     "mean_dice": 0.716313194241331,
#     "dice_defined_cases": 76,
#     "mean_iou": 0.5744556472376638,
#     "iou_defined_cases": 76,
#     "hd95_mm_defined_mean": null,
#     "hd95_mm_defined_cases": 0,
#     "hd95_mm_undefined_cases": 76,
#     "asd_mm_defined_mean": null,
#     "asd_mm_defined_cases": 0,
#     "asd_mm_undefined_cases": 76,
#     "hd95_voxel_defined_mean": null,
#     "hd95_voxel_defined_cases": 0,
#     "hd95_voxel_undefined_cases": 76,
#     "asd_voxel_defined_mean": null,
#     "asd_voxel_defined_cases": 0,
#     "asd_voxel_undefined_cases": 76
#   },
#   "edema_inclusive": {
#     "cases": 76,
#     "status_counts": {
#       "missing_physical_geometry": 76
#     },
#     "mean_dice": 0.7338742730666263,
#     "dice_defined_cases": 76,
#     "mean_iou": 0.592993085552369,
#     "iou_defined_cases": 76,
#     "hd95_mm_defined_mean": null,
#     "hd95_mm_defined_cases": 0,
#     "hd95_mm_undefined_cases": 76,
#     "asd_mm_defined_mean": null,
#     "asd_mm_defined_cases": 0,
#     "asd_mm_undefined_cases": 76,
#     "hd95_voxel_defined_mean": null,
#     "hd95_voxel_defined_cases": 0,
#     "hd95_voxel_undefined_cases": 76,
#     "asd_voxel_defined_mean": null,
#     "asd_voxel_defined_cases": 0,
#     "asd_voxel_undefined_cases": 76
#   },
#   "myocardial_ring": {
#     "cases": 76,
#     "status_counts": {
#       "missing_physical_geometry": 76
#     },
#     "mean_dice": 0.8688394542680946,
#     "dice_defined_cases": 76,
#     "mean_iou": 0.7690805323746673,
#     "iou_defined_cases": 76,
#     "hd95_mm_defined_mean": null,
#     "hd95_mm_defined_cases": 0,
#     "hd95_mm_undefined_cases": 76,
#     "asd_mm_defined_mean": null,
#     "asd_mm_defined_cases": 0,
#     "asd_mm_undefined_cases": 76,
#     "hd95_voxel_defined_mean": null,
#     "hd95_voxel_defined_cases": 0,
#     "hd95_voxel_undefined_cases": 76,
#     "asd_voxel_defined_mean": null,
#     "asd_voxel_defined_cases": 0,
#     "asd_voxel_undefined_cases": 76
#   },
#   "normal_myocardium": {
#     "cases": 76,
#     "status_counts": {
#       "missing_physical_geometry": 76
#     },
#     "mean_dice": 0.764385587890172,
#     "dice_defined_cases": 76,
#     "mean_iou": 0.6248715282913601,
#     "iou_defined_cases": 76,
#     "hd95_mm_defined_mean": null,
#     "hd95_mm_defined_cases": 0,
#     "hd95_mm_undefined_cases": 76,
#     "asd_mm_defined_mean": null,
#     "asd_mm_defined_cases": 0,
#     "asd_mm_undefined_cases": 76,
#     "hd95_voxel_defined_mean": null,
#     "hd95_voxel_defined_cases": 0,
#     "hd95_voxel_undefined_cases": 76,
#     "asd_voxel_defined_mean": null,
#     "asd_voxel_defined_cases": 0,
#     "asd_voxel_undefined_cases": 76
#   },
#   "scar": {
#     "cases": 76,
#     "status_counts": {
#       "missing_physical_geometry": 76
#     },
#     "mean_dice": 0.40145149395244795,
#     "dice_defined_cases": 76,
#     "mean_iou": 0.26069288788204337,
#     "iou_defined_cases": 76,
#     "hd95_mm_defined_mean": null,
#     "hd95_mm_defined_cases": 0,
#     "hd95_mm_undefined_cases": 76,
#     "asd_mm_defined_mean": null,
#     "asd_mm_defined_cases": 0,
#     "asd_mm_undefined_cases": 76,
#     "hd95_voxel_defined_mean": null,
#     "hd95_voxel_defined_cases": 0,
#     "hd95_voxel_undefined_cases": 76,
#     "asd_voxel_defined_mean": null,
#     "asd_voxel_defined_cases": 0,
#     "asd_voxel_undefined_cases": 76
#   },
#   "macro_foreground_dice": 0.627383425361317,
#   "macro_foreground_iou": 0.4866733544703558,
#   "checkpoint": "/content/SCAR/runs/M3/best.pth",
#   "checkpoint_epoch": 46,
#   "ablation": "M3",
#   "split": "test_vol",
#   "case_count": 76,
#   "inference_seconds": 15.746804407002855,
#   "inference_slices_per_second": 29.656810863308724,
#   "timing_note": "Includes transfer and resizing, excludes disk I/O/metrics; first case includes warmup.",
#   "hd95_note": "mm and voxel distances are never mixed. Unknown physical geometry gives null mm HD95. Means include only defined surfaces; inspect counts. Missed lesions have Dice/IoU=0.",
#   "device": "cuda",
#   "amp_dtype": "torch.bfloat16"
# }

# %% [markdown]
# ## Bước 11: Trực quan hóa Biểu đồ Huấn luyện
# Vẽ biểu đồ Loss (Train / Val) và chỉ số hiệu năng phân đoạn (Dice Score, IoU) qua từng epoch từ `metrics.csv`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
metrics_path = Path("/content/SCAR/runs/M2_Pro/metrics.csv")
if not metrics_path.is_file():
    metrics_path = Path("/content/drive/MyDrive/NCKH_V2/SCAR_runs/M2_Pro/metrics.csv")
if metrics_path.is_file():
    metrics = pd.read_csv(metrics_path)
    display(metrics.tail())
    plt.figure(figsize=(14, 5))
    # Đồ thị Loss
    plt.subplot(1, 2, 1)
    plt.plot(metrics["epoch"], metrics["train/loss"], label="Train Loss", color="blue")
    if "val/loss" in metrics.columns:
        plt.plot(metrics["epoch"], metrics["val/loss"], label="Val Loss", color="orange")
    plt.title("Đường cong mất mát (Loss Curve)")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.6)
    # Đồ thị Dice & IoU
    plt.subplot(1, 2, 2)
    if "val/mean_dice" in metrics.columns:
        plt.plot(metrics["epoch"], metrics["val/mean_dice"], label="Val Mean Dice", color="green")
    if "val/mean_iou" in metrics.columns:
        plt.plot(metrics["epoch"], metrics["val/mean_iou"], label="Val Mean IoU", color="purple")
    plt.title("Hiệu năng phân đoạn (Validation Metrics)")
    plt.xlabel("Epoch")
    plt.ylabel("Score")
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ Chưa tìm thấy file metrics.csv tại:", metrics_path)

# %%
# !zip -r /content/SCAR/runs/M2_Pro.zip /content/SCAR/runs/M2_Pro
# Out:
#   adding: content/SCAR/runs/M3/ (stored 0%)
#   adding: content/SCAR/runs/M3/splits/ (stored 0%)
#   adding: content/SCAR/runs/M3/splits/val.txt (deflated 87%)
#   adding: content/SCAR/runs/M3/splits/test_vol.txt (deflated 79%)
#   adding: content/SCAR/runs/M3/splits/split_metadata.json (deflated 85%)
#   adding: content/SCAR/runs/M3/splits/val_vol.txt (deflated 74%)
#   adding: content/SCAR/runs/M3/splits/train.txt (deflated 87%)
#   adding: content/SCAR/runs/M3/train.log (deflated 79%)
#   adding: content/SCAR/runs/M3/last.pth (deflated 7%)
#   adding: content/SCAR/runs/M3/tensorboard/ (stored 0%)
#   adding: content/SCAR/runs/M3/tensorboard/epochs/ (stored 0%)
#   adding: content/SCAR/runs/M3/tensorboard/epochs/events.out.tfevents.1788794166.5f4e3e889432.12561.0 (deflated 71%)
#   adding: content/SCAR/runs/M3/tensorboard/updates/ (stored 0%)
#   adding: content/SCAR/runs/M3/tensorboard/updates/events.out.tfevents.1788794166.5f4e3e889432.12561.1 (deflated 70%)
#   adding: content/SCAR/runs/M3/summary.json (deflated 60%)
#   adding: content/SCAR/runs/M3/best.pth (deflated 7%)
#   adding: content/SCAR/runs/M3/metrics.csv (deflated 56%)
#   adding: content/SCAR/runs/M3/metrics.jsonl (deflated 77%)
#   adding: content/SCAR/runs/M3/config.json (deflated 56%)

# %%
# !cp -r /content/SCAR/runs/M2_Pro /content/drive/MyDrive/
